# %% [markdown]
# # Network programming

# %% [markdown]
# --> network is a co nnection of different nodes/computers that can communicate with each other inorder to perform different actions.

# %% [markdown]
# Network can be classified as:
# 1) LAN
# 2) WAN
# 3) internet

# %% [markdown]
# mobile 1 -----> return1 ----> server -----> router 2 ----> mobile 2

# %% [markdown]
# # Components of network:
# 4. client
# 5. server
# 6. network device(wifi,etheranet)
# 7. protocol
# 8. port
# 9. IP address
